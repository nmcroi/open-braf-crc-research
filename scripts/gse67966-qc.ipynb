# %% [markdown]
# # GSE67966 QC companion
# Run from repository root. Set the local public matrix path; results are computational QC only.

# %%
from pathlib import Path
import subprocess, sys
matrix = Path("/path/to/GSE67966_series_matrix.txt.gz")
subprocess.run([sys.executable, "scripts/qc_gse_matrix.py", str(matrix), "--out", "results/gse67966-qc.json"], check=True)
